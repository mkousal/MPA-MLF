# %% [markdown]
# <a href="https://colab.research.google.com/github/mkousal/MPA-MLF/blob/main/Lab_7/sin_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.optimizers import SGD
from keras.utils import to_categorical
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
from keras.backend import clear_session

# %%
X = np.arange(0, 2*np.pi, 0.0001)
Y = (np.sin(X) + 1)/2

plt.figure()
plt.plot(X, Y)
plt.show()

# %%
clear_session()

# %%
model = Sequential()
model.add(Dense(64, input_dim=(1), activation='sigmoid'))
model.add(Dense(64, activation='tanh'))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='tanh'))
model.add(Dense(1, activation='sigmoid'))

optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)
model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['mean_squared_error'])

# %%
history = model.fit(X, Y, epochs=30)
# Out:
# Epoch 1/30
# 1964/1964 [==============================] - 7s 3ms/step - loss: 0.0233 - mean_squared_error: 0.0233
# Epoch 2/30
# 1964/1964 [==============================] - 6s 3ms/step - loss: 0.0030 - mean_squared_error: 0.0030
# Epoch 3/30
# 1964/1964 [==============================] - 7s 3ms/step - loss: 4.6873e-04 - mean_squared_error: 4.6873e-04
# Epoch 4/30
# 1964/1964 [==============================] - 6s 3ms/step - loss: 3.9063e-04 - mean_squared_error: 3.9063e-04
# Epoch 5/30
# 1964/1964 [==============================] - 7s 3ms/step - loss: 3.5751e-04 - mean_squared_error: 3.5751e-04
# Epoch 6/30
# 1964/1964 [==============================] - 6s 3ms/step - loss: 3.3482e-04 - mean_squared_error: 3.3482e-04
# Epoch 7/30
# 1964/1964 [==============================] - 7s 3ms/step - loss: 3.1817e-04 - mean_squared_error: 3.1817e-04
# Epoch 8/30
# 1964/1964 [==============================] - 6s 3ms/step - loss: 3.0199e-04 - mean_squared_error: 3.0199e-04
# Epoch 9/30
# ...

# %%
loss, accuracy = model.evaluate(X, Y, verbose=0)
print('Accuracy: {:.2f}'.format(accuracy*100))
# Out:
# Accuracy: 0.01

# %%
prediction = model.predict(X)

plt.figure()
plt.plot(X, Y, X, prediction)
plt.show()
# Out:
# 1964/1964 [==============================] - 3s 1ms/step
